# %% [markdown]
# # pycaret install

# %%
# 최적의 모델을 선정하기 위해 여러 모델을 한번에 학습하여 비교해주는 라이브러리 pycaret 설치
# !pip3 install pycaret
from pycaret.classification import *
# Out:
# Requirement already satisfied: pycaret in c:\users\parkg\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: cloudpickle in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (0.10.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (8.15.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: jinja2>=1.2 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (4.1.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: matplotlib<=3.6,>=3.3.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (3.6.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (5.9.2)
# Requirement already satisfied: numba>=0.55.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (0.57.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (1.24.3)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (1.5.3)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (0.9.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: pyod>=1.0.8 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (1.1.1)
# Requirement already satisfied: requests>=2.27.1 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (2.31.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (1.2.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: scipy~=1.10.1 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (1.10.1)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (0.21.1)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (4.65.0)
# Requirement already satisfied: xxhash in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\parkg\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\parkg\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: packaging in c:\users\parkg\anaconda3\lib\site-packages (from deprecation>=2.1.0->pycaret) (23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\parkg\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\parkg\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.11.0)
# Requirement already satisfied: backcall in c:\users\parkg\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in c:\users\parkg\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\parkg\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\parkg\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\parkg\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\parkg\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\parkg\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\parkg\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\parkg\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: colorama in c:\users\parkg\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\parkg\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\parkg\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\parkg\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\parkg\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\parkg\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\parkg\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\parkg\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\parkg\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\parkg\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\parkg\anaconda3\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: fastjsonschema in c:\users\parkg\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\parkg\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\parkg\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.3.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\parkg\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\parkg\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\parkg\anaconda3\lib\site-packages (from plotly>=5.0.0->pycaret) (8.2.2)
# Requirement already satisfied: dash<3.0.0,>=2.11.0 in c:\users\parkg\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.14.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\parkg\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.10)
# Requirement already satisfied: trace-updater>=0.0.8 in c:\users\parkg\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: tsdownsample==0.1.2 in c:\users\parkg\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\parkg\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (3.0.5)
# Requirement already satisfied: urllib3 in c:\users\parkg\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\parkg\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (68.0.0)
# Requirement already satisfied: six in c:\users\parkg\anaconda3\lib\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\parkg\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parkg\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parkg\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2023.7.22)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\parkg\anaconda3\lib\site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: scikit-base<0.6.0 in c:\users\parkg\anaconda3\lib\site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (0.5.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\parkg\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\parkg\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\parkg\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\parkg\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\parkg\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\parkg\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (4.7.1)
# Requirement already satisfied: retrying in c:\users\parkg\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: ansi2html in c:\users\parkg\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\users\parkg\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\parkg\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\parkg\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\parkg\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\parkg\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.4.9)
# Requirement already satisfied: pyzmq>=20 in c:\users\parkg\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\parkg\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\parkg\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\parkg\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\parkg\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\parkg\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\parkg\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (305.1)
# Requirement already satisfied: wcwidth in c:\users\parkg\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: executing in c:\users\parkg\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\parkg\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\parkg\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\parkg\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\parkg\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: entrypoints in c:\users\parkg\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# # 한글 깨짐 현상 (반영안되면 런타임 초기화 해주세요)

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# 'sudo'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'sudo'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
import matplotlib.pyplot as plt

plt.rc('font', family = 'NanumGothic')

# %% [markdown]
# # 데이터 불러오기와 다듬기

# %%
import pandas as pd

raw_hitters = pd.read_csv('../raw_data/2015~2022 hitters.csv', encoding = 'utf-8')
raw_pitchers = pd.read_csv('../raw_data/2015~2022 pitchers.csv')

print(raw_hitters.columns,'\n',raw_pitchers.columns)
# Out:
# Index(['순', '이름', '팀', 'WAR*', 'G', '타석', '타수', '득점', '안타', '2타', '3타', '홈런',
#        '루타', '타점', '도루', '도실', '볼넷', '사구', '고4', '삼진', '병살', '희타', '희비', '타율',
#        '출루', '장타', 'OPS', 'wOBA', 'wRC+', 'WAR*.1', 'WPA'],
#       dtype='object')
#  Index(['순', '이름', '팀', 'WAR', '출장', '완투', '완봉', '선발', '승', '패', '세', '홀드',
#        '이닝', '실점', '자책', '타자', '안타', '2타', '3타', '홈런', '볼넷', '고4', '사구', '삼진',
#        '보크', '폭투', 'ERA', 'FIP', 'WHIP', 'ERA+', 'FIP+', 'WAR(need to drop)',
#        'WPA'],
#       dtype='object')

# %%
# 필요없는 feature 삭제
raw_hitters.drop(['순','WAR*.1'], axis = 1, inplace = True)
raw_pitchers.drop(['순','WAR(need to drop)'], axis = 1, inplace = True)

# %%
# 타자 데이터의 결합된 소속팀, 연도, 포지션 데이터 분리
hitters_team = raw_hitters.팀

team,year,position = [],[],[]

for x in hitters_team:
  if len(x) < 4:
    x = x + 'XX'
  y = str(20) + x[0:2]
  t = x[2]
  p = x[3:]

  year.append(y)
  team.append(t)
  position.append(p)

raw_hitters['소속팀'] = team
raw_hitters['연도'] = year
raw_hitters['포지션'] = position

raw_hitters.drop('팀', axis = 1, inplace = True)

hit_col=raw_hitters.columns

# %%
# 투수 데이터의 결합된 소속팀, 연도, 포지션 데이터 분리

pitchers_team = raw_pitchers.팀

team,year = [],[]

for x in pitchers_team:
  y = str(20) + x[0:2]
  t = x[2]

  year.append(y)
  team.append(t)

raw_pitchers['소속팀'] = team
raw_pitchers['연도'] = year

raw_pitchers.drop('팀', axis = 1, inplace = True)

pit_col = raw_pitchers.columns

# %% [markdown]
# # 연봉 데이터 가져와서 붙이기

# %%
# 여러 csv에서 dataframe을 가져와 concat
salary = pd.DataFrame()
for year in range(2016, 2024):
  temp = pd.read_csv('../raw_data/'+ str(year) +' salary.csv')
  salary = pd.concat([salary, temp])

# %%
# 팀 이름이 바뀐 경우 처리
salary.rename(columns = {'팀':'소속팀'}, inplace=True)
salary.rename(columns = {'선수':'이름'}, inplace=True)

salary.loc[salary['소속팀'] == '넥센', '소속팀'] = '키움'
salary.loc[salary['소속팀'] == 'SK', '소속팀'] = 'SSG'
salary['연도'] = salary['연도'].apply(str)
salary.sort_values(by = ["연도", '이름'], ascending = True, inplace = True)
salary.reset_index(drop = True, inplace = True)
salary['연봉']= salary['연봉'].str.replace(pat=r'[^\w]', repl=r'', regex = True)

# %%
salary.소속팀.unique()
# Out:
# array(['한화', 'NC', '롯데', '두산', 'LG', 'kt', '키움', 'KIA', 'SSG', '삼성',
#        '2021'], dtype=object)

# %%
# 결측치 처리(호세 로사도와 대럴 케네디는 한화의 2021년도 코치임)
salary[salary['소속팀'] == '2021']
# Out:
#       이름   연도   소속팀  연봉    WAR
# 5414  호세  로사도  2021  한화  3,000
# 5415  대럴  케네디  2021  한화  3,000

# %%
idx = salary[salary['소속팀'] == '2021'].index
salary.drop(idx, axis = 0, inplace = True)
salary.drop(['WAR'], axis = 1, inplace = True)
salary['연봉'] = pd.to_numeric(salary['연봉'])
salary['연도'] = pd.to_numeric(salary['연도'])

# %%
# 시계열 분석(전년도 성적을 바탕으로 올해 연봉을 예측)을 위해 전년도 데이터와 올해 연봉을 매칭
salary.to_csv('salary.csv', index = False)

salary['연도'] = salary['연도'] - 1
salary.연도.unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022], dtype=int64)

# %%
# KIA와 kt의 데이터가 구분이 되지 않는 문제 관측
raw_hitters.소속팀.value_counts()
# Out:
# K    366
# 한    251
# 삼    228
# L    228
# N    223
# 롯    221
# S    216
# 두    208
# 키    105
# 넥    103
# k     86
# Name: 소속팀, dtype: int64

# %%
# 소속팀 k의 데이터는 16, 17년에만 존재하는 것을 확인
raw_hitters.loc[raw_hitters['소속팀'] == 'k'].head()
# Out:
#       이름  WAR*    G   타석   타수  득점   안타  2타  3타  홈런  ...     타율     출루     장타  \
# 77   마르테  4.83  115  487  425  85  148  32   1  20  ...  0.348  0.414  0.569
# 97   박경수  4.57  137  537  440  75  125  30   1  22  ...  0.284  0.399  0.507
# 133  박경수  4.04  121  476  402  64  126  22   1  20  ...  0.313  0.412  0.522
# 213  유한준  3.29  110  460  408  70  137  22   0  14  ...  0.336  0.404  0.493
# 303  로하스  2.53   83  367  336  52  101  27   3  18  ...  0.301  0.352  0.560
#
#        OPS   wOBA   wRC+   WPA  소속팀    연도  포지션
# 77   0.983  0.424  149.0  3.20    k  2015   3B
# 97   0.906  0.397  131.0  1.12    k  2015   2B
# 133  0.934  0.415  135.0  2.22    k  2016   2B
# 213  0.897  0.405  128.6  3.42    k  2016   RF
# 303  0.911  0.388  124.7  1.44    k  2017   CF
#
# [5 rows x 31 columns]

# %%
# 2017년 전까지는 k는 kt K는 KIA를 의미했지만 그 이후에는 모두 K로 표기된 것을 확인
raw_hitters.loc[(raw_hitters['소속팀'] == 'K') & ((raw_hitters['연도'] == '2016') | (raw_hitters['연도'] == '2017'))].head(5)
# Out:
#        이름  WAR*    G   타석   타수   득점   안타  2타  3타  홈런  ...     타율     출루  \
# 15    최형우  6.66  142  629  514   98  176  36   3  26  ...  0.342  0.450
# 55   버나디나  5.12  139  621  557  118  178  26   8  27  ...  0.320  0.372
# 64    김선빈  4.96  137  529  476   84  176  34   1   5  ...  0.370  0.420
# 111   안치홍  4.39  132  545  487   95  154  29   2  21  ...  0.316  0.373
# 114   이범호  4.36  138  560  484   93  150  23   0  33  ...  0.310  0.391
#
#         장타    OPS   wOBA   wRC+   WPA  소속팀    연도  포지션
# 15   0.576  1.026  0.442  163.5  5.45    K  2017   LF
# 55   0.540  0.913  0.390  128.4  3.83    K  2017   CF
# 64   0.477  0.897  0.399  134.0  1.92    K  2017   SS
# 111  0.513  0.886  0.382  123.0  3.80    K  2017   2B
# 114  0.562  0.953  0.411  132.9  3.95    K  2016   3B
#
# [5 rows x 31 columns]

# %%
# 결측치를 줄이기 위해 16, 17년, k와 K 데이터를 나누어 줌
raw_hitters['연도'] = pd.to_numeric(raw_hitters['연도'])
raw_pitchers['연도'] = pd.to_numeric(raw_pitchers['연도'])
hitters_k = raw_hitters[(raw_hitters['소속팀'] == 'K') & (raw_hitters['연도'] > 2017)]
hitters_notk = raw_hitters[(raw_hitters['소속팀'] != 'K') | (raw_hitters['연도'] <= 2017)]
pitchers_k = raw_pitchers[(raw_pitchers['소속팀'] == 'K') & (raw_pitchers['연도'] > 2017)]
pitchers_notk = raw_pitchers[(raw_pitchers['소속팀'] != 'K') | (raw_pitchers['연도'] <= 2017)]

# %%
def name(df):
    df.loc[df['소속팀'] == '키', '소속팀'] = '키움'
    df.loc[df['소속팀'] == '넥', '소속팀'] = '키움'
    df.loc[df['소속팀'] == '삼', '소속팀'] = '삼성'
    df.loc[df['소속팀'] == '두', '소속팀'] = '두산'
    df.loc[df['소속팀'] == '한', '소속팀'] = '한화'
    df.loc[df['소속팀'] == '롯', '소속팀'] = '롯데'
    df.loc[df['소속팀'] == 'k', '소속팀'] = 'kt'       # 소문자 'k'는 'kt'로
    df.loc[df['소속팀'] == 'K', '소속팀'] = 'KIA'     # 대문자 'K'는 'KIA'로
    df.loc[df['소속팀'] == 'L', '소속팀'] = 'LG'
    df.loc[df['소속팀'] == 'S', '소속팀'] = 'SSG'
    df.loc[df['소속팀'] == 'N', '소속팀'] = 'NC'
    return df

# %%
hitters_notk = name(hitters_notk)
pitchers_notk = name(pitchers_notk)

# %%
hitters_k = pd.merge(hitters_k, salary, how = "left", on = ['이름', '연도'])
hitters_notk = pd.merge(hitters_notk, salary, how = "left", on = ['이름', '연도', '소속팀'])
pitchers_k = pd.merge(pitchers_k, salary, how = "left", on = ['이름', '연도'])
pitchers_notk = pd.merge(pitchers_notk, salary, how = "left", on = ['이름', '연도', '소속팀'])

# %%
hitters_k.columns
# Out:
# Index(['이름', 'WAR*', 'G', '타석', '타수', '득점', '안타', '2타', '3타', '홈런', '루타', '타점',
#        '도루', '도실', '볼넷', '사구', '고4', '삼진', '병살', '희타', '희비', '타율', '출루', '장타',
#        'OPS', 'wOBA', 'wRC+', 'WPA', '소속팀_x', '연도', '포지션', '소속팀_y', '연봉'],
#       dtype='object')

# %%
# 나뉜 hitter data를 concat
hitters_k = hitters_k[['이름', 'WAR*', 'G', '타석', '타수', '득점', '안타',
                       '2타', '3타', '홈런', '루타', '타점', '도루', '도실',
                       '볼넷', '사구', '고4', '삼진', '병살', '희타', '희비',
                       '타율', '출루', '장타', 'OPS', 'wOBA', 'wRC+', 'WPA',
                       '소속팀_y', '연도', '포지션', '연봉']]
hitters_k = hitters_k.rename(columns = {'소속팀_y':'소속팀'})
hitters = pd.concat([hitters_k, hitters_notk])

# %%
pitchers_k.columns
# Out:
# Index(['이름', 'WAR', '출장', '완투', '완봉', '선발', '승', '패', '세', '홀드', '이닝', '실점',
#        '자책', '타자', '안타', '2타', '3타', '홈런', '볼넷', '고4', '사구', '삼진', '보크', '폭투',
#        'ERA', 'FIP', 'WHIP', 'ERA+', 'FIP+', 'WPA', '소속팀_x', '연도', '소속팀_y',
#        '연봉'],
#       dtype='object')

# %%
# 나뉜 pitcher data를 concat
pitchers_k = pitchers_k[['이름', 'WAR', '출장', '완투', '완봉', '선발', '승',
                       '패', '세', '홀드', '이닝', '실점', '자책', '타자',
                       '안타', '2타', '3타', '홈런', '볼넷', '고4', '사구',
                       '삼진', '보크', '폭투', 'ERA', 'FIP', 'WHIP', 'ERA+',
                       'FIP+', 'WPA', '소속팀_y', '연도', '연봉']]
pitchers_k = pitchers_k.rename(columns = {'소속팀_y':'소속팀'})
pitchers = pd.concat([pitchers_k, pitchers_notk])

# %%
hitters.sort_values(['WAR*'], ascending = False, inplace = True)
hitters.reset_index(drop = True)
# Out:
#        이름   WAR*    G   타석   타수   득점   안타  2타  3타  홈런  ...     출루     장타  \
# 0     테임즈  10.71  142  595  472  130  180  42   5  47  ...  0.498  0.790
# 1     이정후   9.23  142  627  553   85  193  36  10  23  ...  0.421  0.575
# 2     박병호   7.76  140  622  528  129  181  35   1  53  ...  0.436  0.714
# 3     로하스   7.76  142  628  550  116  192  39   1  47  ...  0.417  0.680
# 4     최형우   7.75  138  618  519   99  195  46   2  31  ...  0.464  0.651
# ...   ...    ...  ...  ...  ...  ...  ...  ..  ..  ..  ...    ...    ...
# 2246  조인성  -1.36   76  146  137   10   23   2   0   3  ...  0.186  0.248
# 2247  강한울  -1.39   90  292  264   30   54   8   3   0  ...  0.250  0.258
# 2248  나종덕  -1.41  104  209  185   12   23   4   0   3  ...  0.188  0.195
# 2249  김헌곤  -1.58   80  239  224   18   43   8   0   1  ...  0.224  0.241
# 2250  나종덕  -1.71  106  203  177   15   22   3   0   2  ...  0.201  0.175
#
#         OPS   wOBA   wRC+   WPA  소속팀    연도  포지션       연봉
# 0     1.288  0.530  222.3  7.02   NC  2015   1B      0.0
# 1     0.996  0.441  182.5  6.72   키움  2022   CF  75000.0
# 2     1.150  0.481  181.9  7.82   키움  2015   1B      NaN
# 3     1.097  0.467  180.5  7.29  NaN  2020   RF      NaN
# 4     1.116  0.480  177.8  5.50   삼성  2016   LF      NaN
# ...     ...    ...    ...   ...  ...   ...  ...      ...
# 2246  0.434  0.188  -12.4 -1.88   한화  2016    C      NaN
# 2247  0.508  0.229   18.5 -1.36  KIA  2015   SS   6000.0
# 2248  0.383  0.180   -4.2 -2.74   롯데  2019    C   4300.0
# 2249  0.465  0.217   24.6 -2.24   삼성  2022   CF  18000.0
# 2250  0.376  0.175  -15.1 -1.85   롯데  2018    C      NaN
#
# [2251 rows x 32 columns]

# %%
hitters.연봉.isna().value_counts()
# Out:
# False    1447
# True      804
# Name: 연봉, dtype: int64

# %%
pitchers.sort_values(['WAR'], ascending = False, inplace = True)
pitchers.reset_index(drop = True)
# Out:
#          이름   WAR  출장  완투  완봉  선발   승   패  세  홀드  ...  폭투    ERA   FIP  WHIP  \
# 0      알칸타라  8.31  31   1   0  31  20   2  0   0  ...   3   2.54  3.10  1.03
# 1       양현종  8.14  32   1   1  31  15   6  0   1  ...   6   2.44  4.57  1.24
# 2       안우진  7.92  30   1   0  30  15   8  0   0  ...   7   2.11  2.21  0.95
# 3     스트레일리  7.53  31   0   0  31  15   4  0   0  ...   4   2.50  3.01  1.02
# 4     스트레일리  7.53  31   0   0  31  15   4  0   0  ...   4   2.50  3.01  1.02
# ...     ...   ...  ..  ..  ..  ..  ..  .. ..  ..  ...  ..    ...   ...   ...
# 2049    장시환 -1.38  19   1   0  16   0  11  0   1  ...   7   7.04  4.99  1.96
# 2050    유희관 -1.48  15   0   0  15   4   7  0   0  ...   0   7.71  5.95  2.08
# 2051    배영수 -1.55  32   0   0  21   4  11  0   1  ...   6   7.04  6.78  1.61
# 2052    장현식 -1.67  37   0   0   3   4   4  0   6  ...  11  10.76  6.65  2.10
# 2053    장원준 -2.19  24   0   0  16   3   7  0   2  ...   3   9.92  6.57  1.87
#
#        ERA+   FIP+   WPA  소속팀    연도       연봉
# 0     182.6  149.7  4.35   두산  2020      NaN
# 1     202.1  108.5  3.94  KIA  2015  75000.0
# 2     189.3  179.1  5.65   키움  2022  15000.0
# 3     195.1  159.0  3.84   롯데  2020  90000.0
# 4     195.1  159.0  3.84   롯데  2020  50000.0
# ...     ...    ...   ...  ...   ...      ...
# 2049   62.2   89.5 -2.32   한화  2021   8700.0
# 2050   55.9   71.8 -1.98   두산  2021      NaN
# 2051   70.8   72.9 -3.88   한화  2015  55000.0
# 2052   44.8   72.2 -2.09   NC  2020      NaN
# 2053   51.0   76.4 -3.12   두산  2018      NaN
#
# [2054 rows x 33 columns]

# %%
pitchers.연봉.isna().value_counts()
# Out:
# False    1308
# True      746
# Name: 연봉, dtype: int64

# %%
hitters.to_csv('../raw_data/hitters_info_salary.csv', index = False)
pitchers.to_csv('../raw_data/pitchers_info_salary.csv', index = False)

# %% [markdown]
# # Salary 결측값 및 0 drop

# %%
hitter = pd.read_csv('../raw_data/hitters_info_salary.csv')
pitcher = pd.read_csv('../raw_data/pitchers_info_salary.csv')

# %%
# salary가 NaN인 hitter 데이터 drop
hitter.dropna(subset = ['연봉'], inplace = True)
hitter = hitter[hitter['연봉'] != 0]
hitter.reset_index(drop = True, inplace = True)
hitter.head(5)
# Out:
#     이름  WAR*    G   타석   타수   득점   안타  2타  3타  홈런  ...     출루     장타    OPS  \
# 0  이정후  9.23  142  627  553   85  193  36  10  23  ...  0.421  0.575  0.996
# 1  김재환  7.46  144  636  544  110  185  34   2  35  ...  0.429  0.603  1.032
# 2  피렐라  7.40  141  630  561  102  192  33   4  28  ...  0.411  0.565  0.976
# 3  김하성  7.17  139  625  540  112  166  38   2  19  ...  0.389  0.491  0.880
# 4  박건우  7.01  131  543  483   91  177  40   2  20  ...  0.424  0.582  1.006
#
#     wOBA   wRC+   WPA  소속팀    연도  포지션       연봉
# 0  0.441  182.5  6.72   키움  2022   CF  75000.0
# 1  0.440  170.9  7.45   두산  2017   LF  47000.0
# 2  0.434  169.3  4.20   삼성  2022   LF  60000.0
# 3  0.397  145.7  4.52   키움  2019   SS  32000.0
# 4  0.433  163.8  2.76   두산  2017   CF  37000.0
#
# [5 rows x 32 columns]

# %%
# salary가 NaN인 pitcher 데이터 drop
pitcher.dropna(subset = ['연봉'], inplace = True)
pitcher = pitcher[pitcher['연봉'] != 0]
pitcher.reset_index(drop = True, inplace = True)
pitcher.head(5)
# Out:
#       이름   WAR  출장  완투  완봉  선발   승  패  세  홀드  ...  폭투   ERA   FIP  WHIP  \
# 0    양현종  8.14  32   1   1  31  15  6  0   1  ...   6  2.44  4.57  1.24
# 1    안우진  7.92  30   1   0  30  15  8  0   0  ...   7  2.11  2.21  0.95
# 2  스트레일리  7.53  31   0   0  31  15  4  0   0  ...   4  2.50  3.01  1.02
# 3  스트레일리  7.53  31   0   0  31  15  4  0   0  ...   4  2.50  3.01  1.02
# 4    양현종  7.35  29   2   2  29  16  8  0   0  ...   1  2.29  2.63  1.07
#
#     ERA+   FIP+   WPA  소속팀    연도        연봉
# 0  202.1  108.5  3.94  KIA  2015   75000.0
# 1  189.3  179.1  5.65   키움  2022   15000.0
# 2  195.1  159.0  3.84   롯데  2020   90000.0
# 3  195.1  159.0  3.84   롯데  2020   50000.0
# 4  183.1  160.3  3.81  KIA  2019  230000.0
#
# [5 rows x 33 columns]

# %% [markdown]
# # 연봉~columns 간의 관계 - 타자

# %%
hitter.columns
# Out:
# Index(['이름', 'WAR*', 'G', '타석', '타수', '득점', '안타', '2타', '3타', '홈런', '루타', '타점',
#        '도루', '도실', '볼넷', '사구', '고4', '삼진', '병살', '희타', '희비', '타율', '출루', '장타',
#        'OPS', 'wOBA', 'wRC+', 'WPA', '소속팀', '연도', '포지션', '연봉'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# hitter의 salary 분포 확인
sa = hitter['연봉']
sns.violinplot(x = sa)

plt.title('Salary distribution (Violin)')
plt.show()

print(sa.describe())
# Out:
# count      1371.000000
# mean      19360.765864
# std       32299.792920
# min        2700.000000
# 25%        3400.000000
# 50%        6000.000000
# 75%       20750.000000
# max      250000.000000
# Name: 연봉, dtype: float64

# %%
# hitter의 salary 분포 확인

temp = hitter[['WAR*','연봉']]

plt.scatter(temp['WAR*'], temp.연봉, color = 'red', s = 1)
plt.xlabel('WAR*')
plt.ylabel('Salary(log scaled)')
plt.yscale('log')
plt.title('WAR* ~ Salary')
plt.show()

# %%
temp = hitter[['WPA','연봉']]

plt.scatter(temp['WPA'], temp.연봉, color = 'black', s = 1)
plt.xlabel('WPA')
plt.ylabel('Log Salary')
plt.yscale('log')
plt.title('WPA ~ Salary')
plt.show()

# %% [markdown]
# WPA와 WAR가 비슷한 형태를 띄고 있습니다. 아마 WAR은 승리기여도이고, WPA는 승리확률기여도를 의미하기 때문이겠죠?

# %%
temp = hitter[['wOBA','연봉']]

plt.scatter([i * 1000 for i in temp['wOBA']], temp.연봉, color = 'orange', s = 1)
plt.xlabel('wOBA*1000')
plt.ylabel('Log Salary')
plt.yscale('log')
plt.title('wOBA ~ Salary')
plt.show()

# %%
temp = hitter[['OPS','연봉']]

plt.scatter([i * 1000 for i in temp['OPS']], temp.연봉, color = 'blue', s = 1)
plt.xlabel('OPS*1000')
plt.ylabel('Log Salary')
plt.yscale('log')
plt.title('OPS ~ Salary')
plt.show()

# %%
temp = hitter[['wRC+','연봉']]

plt.scatter([i +100 for i in temp['wRC+']], temp.연봉, color = 'green', s = 1)
plt.xlabel('wRC+')
plt.ylabel('Log Salary')
plt.yscale('log')
plt.title('wRC+ ~ Salary')
plt.show()

# %% [markdown]
# wOBA, OPS와 wRC+ 역시 유사한 모습을 보입니다.<br/> 아마 셋다 장타율에 관련된 요소가 작용하는 듯 합니다.

# %%
temp = hitter[['타석','연봉']]

plt.scatter(temp['타석'], temp.연봉, color = 'purple', s = 1)
plt.xlabel('at bat')
plt.ylabel('Log Salary')
plt.yscale('log')
plt.title('at Bat ~ Salary')
plt.show()

# %%
temp = hitter[['득점','연봉']]

plt.scatter(temp['득점'], temp.연봉, color = 'purple', s = 1)
plt.xlabel('s')
plt.ylabel('Log Salary')
plt.yscale('log')
plt.title('s ~ Salary')
plt.show()

# %%
temp = hitter[['타점','연봉']]

plt.scatter(temp['타점'], temp.연봉, color = 'purple', s = 1)
plt.xlabel('score by Hit')
plt.ylabel('Log Salary')
plt.yscale('log')
plt.title('score by Hit ~ Salary')
plt.show()

# %% [markdown]
# 득점, 타석, 타점과 연봉의 관계입니다 <br/> 생각보다는 관련이 없어보이긴 하네요

# %% [markdown]
# # 연봉~columns 간의 관계 - 투수

# %%
pitcher.columns
# Out:
# Index(['이름', 'WAR', '출장', '완투', '완봉', '선발', '승', '패', '세', '홀드', '이닝', '실점',
#        '자책', '타자', '안타', '2타', '3타', '홈런', '볼넷', '고4', '사구', '삼진', '보크', '폭투',
#        'ERA', 'FIP', 'WHIP', 'ERA+', 'FIP+', 'WPA', '소속팀', '연도', '연봉'],
#       dtype='object')

# %%
sa = pitcher['연봉']
sns.violinplot(x = sa)

plt.title('Salary distribution (Violin)')
plt.show()

print(sa.describe())
# Out:
# count      1240.000000
# mean      16225.216129
# std       26809.405907
# min        2700.000000
# 25%        3500.000000
# 50%        6300.000000
# 75%       15000.000000
# max      230000.000000
# Name: 연봉, dtype: float64

# %% [markdown]
# 고액 연봉자들과 저액연봉자들의 격차가 큼을 확인 <br/>-> 이를 바탕으로 label 설정하면 될듯!

# %%
temp = pitcher[['WAR','연봉']]

plt.scatter(temp['WAR'], temp.연봉, color='red', s = 1)
plt.xlabel('WAR')
plt.ylabel('Salary(log scaled)')
plt.yscale('log')
plt.title('WAR ~ Salary')
plt.show()

# %%
temp = pitcher[['WPA','연봉']]

plt.scatter(temp['WPA'], temp.연봉, color='black', s = 1)
plt.xlabel('WPA')
plt.ylabel('Log Salary')
plt.yscale('log')
plt.title('WPA ~ Salary')
plt.show()

# %% [markdown]
# WPA와 WAR가 비슷한 형태를 띄고 있습니다. 아마 WAR은 승리기여도이고, WPA는 승리확률기여도를 의미하기 때문이겠죠?

# %% [markdown]
# # 연봉 데이터 label 넣어주기

# %%
def assign_label(value):
    if value <= q50:
        return 1
    elif value <= q75:
        return 2
    else:
        return 3

q50 = hitter['연봉'].quantile(0.50)
q75 = hitter['연봉'].quantile(0.75)

hitter['label'] = hitter['연봉'].apply(assign_label)
hitter.drop(['연봉'], axis = 1, inplace = True)
hitter['label'].value_counts()
# Out:
# 1    695
# 3    343
# 2    333
# Name: label, dtype: int64

# %%
def assign_label(value):
    if value <= q50:
        return 1
    elif value <= q75:
        return 2
    else:
        return 3

q50 = pitcher['연봉'].quantile(0.50)
q75 = pitcher['연봉'].quantile(0.75)

pitcher['label'] = pitcher['연봉'].apply(assign_label)
pitcher.drop(['연봉'], axis = 1, inplace = True)
pitcher
# Out:
#          이름   WAR  출장  완투  완봉  선발   승   패  세  홀드  ...  폭투   ERA   FIP  WHIP  \
# 0       양현종  8.14  32   1   1  31  15   6  0   1  ...   6  2.44  4.57  1.24
# 1       안우진  7.92  30   1   0  30  15   8  0   0  ...   7  2.11  2.21  0.95
# 2     스트레일리  7.53  31   0   0  31  15   4  0   0  ...   4  2.50  3.01  1.02
# 3     스트레일리  7.53  31   0   0  31  15   4  0   0  ...   4  2.50  3.01  1.02
# 4       양현종  7.35  29   2   2  29  16   8  0   0  ...   1  2.29  2.63  1.07
# ...     ...   ...  ..  ..  ..  ..  ..  .. ..  ..  ...  ..   ...   ...   ...
# 1235    황동재 -1.29  16   0   0  13   1   3  0   0  ...   1  7.06  4.91  1.84
# 1236    김대우 -1.32  25   0   0   7   2   5  0   1  ...   2  9.54  6.48  1.94
# 1237    윤대경 -1.37  25   0   0  14   4   9  0   0  ...   5  7.41  3.98  1.63
# 1238    장시환 -1.38  19   1   0  16   0  11  0   1  ...   7  7.04  4.99  1.96
# 1239    배영수 -1.55  32   0   0  21   4  11  0   1  ...   6  7.04  6.78  1.61
#
#        ERA+   FIP+   WPA  소속팀    연도  label
# 0     202.1  108.5  3.94  KIA  2015      3
# 1     189.3  179.1  5.65   키움  2022      2
# 2     195.1  159.0  3.84   롯데  2020      3
# 3     195.1  159.0  3.84   롯데  2020      3
# 4     183.1  160.3  3.81  KIA  2019      3
# ...     ...    ...   ...  ...   ...    ...
# 1235   59.2   84.6 -1.89   삼성  2022      1
# 1236   53.2   77.7 -2.63   삼성  2017      2
# 1237   54.7  102.6 -2.23   한화  2022      2
# 1238   62.2   89.5 -2.32   한화  2021      2
# 1239   70.8   72.9 -3.88   한화  2015      3
#
# [1240 rows x 33 columns]

# %% [markdown]
# # RF기준으로 피처 상관관계

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X_hit=hitter.drop(['index','label','이름','소속팀','포지션','연도'], axis = 1)
Y_hit=hitter['label']

feature_names = X_hit.columns

X_hit_train, X_hit_test, Y_hit_train, Y_hit_test = train_test_split(X_hit, Y_hit, test_size = 0.2, random_state = 123)


clf_hit = RandomForestClassifier(n_estimators = 100, random_state = 42)
clf_hit.fit(X_hit_train, Y_hit_train)

importances = clf_hit.feature_importances_
# print(len(importances),len(feature_names))

df_importances_hit = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
})
df_importances_hit = df_importances_hit.sort_values(by = 'Importance', ascending = False)

plt.bar(df_importances_hit['Feature'], df_importances_hit['Importance'])
plt.ylabel('Importance')
plt.title('Feature Importances using Random Forest')
plt.xticks(rotation = 45)
plt.show()

df_importances_hit.reset_index(drop = True,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\parkg\OneDrive\문서\GitHub\SKKU\GCO2011(23-2)_IntroML\codes\KBO_Salary_Prediction.ipynb 셀 64 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/parkg/OneDrive/%EB%AC%B8%EC%84%9C/GitHub/SKKU/GCO2011%2823-2%29_IntroML/codes/KBO_Salary_Prediction.ipynb#Y121sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.ensemble import RandomForestClassifier
#       <a href='vscode-notebook-cell:/c%3A/Users/parkg/OneDrive/%EB%AC%B8%EC%84%9C/GitHub/SKKU/GCO2011%2823-2%29_IntroML/codes/KBO_Salary_Prediction.ipynb#Y121sZmlsZQ%3D%3D?line=1'>2</a> from sklearn.model_selection import train_test_split
# ----> <a href='vscode-notebook-cell:/c%3A/Users/parkg/OneDrive/%EB%AC%B8%EC%84%9C/GitHub/SKKU/GCO2011%2823-2%29_IntroML/codes/KBO_Salary_Prediction.ipynb#Y121sZmlsZQ%3D%3D?line=3'>4</a> X_hit=hitter.drop(['index','label','이름','소속팀','포지션','연도'], axis = 1)
#       <a href='vscode-notebook-cell:/c%3A/Users/parkg/OneDrive/%EB%AC%B8%EC%84%9C/GitHub/SKKU/GCO2011%2823-2%29_IntroML/codes/KBO_Salary_Prediction.ipynb#Y121sZmlsZQ%3D%3D?line=4'>5</a> Y_hit=hitter['label']
#       <a href='vscode-notebook-cell:/c%3A/Users/parkg/OneDrive/%EB%AC%B8%EC%84%9C/GitHub/SKKU/GCO2011%2823-2%29_IntroML/codes/KBO_Salary_Prediction.ipynb#Y121sZmlsZQ%3D%3D?line=6'>7</a> feature_names = X_hit.columns
#
# File c:\Users\parkg\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\parkg\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File c:\Users\parkg\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\parkg\anaconda3\Lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Users\parkg\anaconda3\Lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Users\parkg\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
from sklearn.ensemble import RandomForestClassifier

X_pit=pitcher.drop(['index','label','이름','소속팀','연도'], axis = 1)
Y_pit=pitcher['label']

feature_names = X_pit.columns

X_pit_train, X_pit_test, Y_pit_train, Y_pit_test = train_test_split(X_pit, Y_pit, test_size = 0.2, random_state = 123)

clf_pit = RandomForestClassifier(n_estimators = 100, random_state = 42)
clf_pit.fit(X_pit_train, Y_pit_train)

importances = clf_pit.feature_importances_
# print(len(importances),len(feature_names))

df_importances_pit = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
})
df_importances_pit = df_importances_pit.sort_values(by = 'Importance', ascending = False)

plt.bar(df_importances_pit['Feature'], df_importances_pit['Importance'])
plt.ylabel('Importance')
plt.title('Feature Importances using Random Forest')
plt.xticks(rotation = 45)
plt.show()

df_importances_pit.reset_index(drop = True, inplace = True)
df_importances_pit[:10]
# Out:
#   Feature  Importance
# 0      삼진    0.091868
# 1      이닝    0.086056
# 2      타자    0.063080
# 3     WAR    0.060142
# 4      출장    0.056421
# 5    WHIP    0.043528
# 6     WPA    0.043060
# 7      안타    0.042488
# 8     FIP    0.041378
# 9      홀드    0.039773

# %%
print('RF 기준 상위 10개 출력\n 타자의 피처중요도: \n{0}\n\n투수의 피처중요도: \n{1}'.format(df_importances_hit['Feature'][:10],df_importances_pit['Feature'][:10]))
# Out:
# RF 기준 상위 10개 출력
#  타자의 피처중요도:
# 0      루타
# 1      타석
# 2      안타
# 3      타수
# 4      타점
# 5       G
# 6      볼넷
# 7    WAR*
# 8      득점
# 9      삼진
# Name: Feature, dtype: object
#
# 투수의 피처중요도:
# 0      삼진
# 1      이닝
# 2      타자
# 3     WAR
# 4      출장
# 5    WHIP
# 6     WPA
# 7      안타
# 8     FIP
# 9      홀드
# Name: Feature, dtype: object

# %% [markdown]
# # 필요한 칼럼끼리 정규화

# %%
hit_columns = df_importances_hit['Feature'][:10].tolist()
pit_columns = df_importances_pit['Feature'][:10].tolist()

hit_columns.append('label')
pit_columns.append('label')

hitter_data = hitter[hit_columns]
pitcher_data = pitcher[pit_columns]

# %%
from sklearn.model_selection import train_test_split

X_hitter = hitter_data.drop(['label'],axis=1)
Y_hitter = hitter['label']
X_hitter_train, X_hitter_test, Y_hitter_train, Y_hitter_test = train_test_split(X_hitter, Y_hitter, test_size = 0.3, random_state = 0)

X_pitcher = pitcher_data.drop(['label'],axis=1)
Y_pitcher = pitcher_data['label']
X_pitcher_train, X_pitcher_test, Y_pitcher_train, Y_pitcher_test = train_test_split(X_pitcher, Y_pitcher, test_size = 0.3, random_state = 0)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

ct_hit = ColumnTransformer([("scaling", StandardScaler(), hit_columns[:-1])])
ct_hit.fit(X_hitter_train)

X_hitter_train = ct_hit.transform(X_hitter_train)
X_hitter_test = ct_hit.transform(X_hitter_test)

ct_pit = ColumnTransformer([("scaling", StandardScaler(), pit_columns[:-1])])
ct_pit.fit(X_pitcher_train)

X_pitcher_train = ct_pit.transform(X_pitcher_train)
X_pitcher_test = ct_pit.transform(X_pitcher_test)

# %% [markdown]
# # pycaret - 타자

# %%
from pycaret.classification import *
import numpy as np

exp1 = setup(data = hitter_data, target = 'label')
best_model = compare_models(n_select = 10)
# Out:
# <style type="text/css">
# #T_232bd_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_232bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_232bd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_232bd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_232bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_232bd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_232bd_row0_col1" class="data row0 col1" >8968</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_232bd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_232bd_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_232bd_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_232bd_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_232bd_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_232bd_row3_col1" class="data row3 col1" >1: 0, 2: 1, 3: 2</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_232bd_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_232bd_row4_col1" class="data row4 col1" >(1371, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_232bd_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_232bd_row5_col1" class="data row5 col1" >(1371, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_232bd_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_232bd_row6_col1" class="data row6 col1" >(959, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_232bd_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_232bd_row7_col1" class="data row7 col1" >(412, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_232bd_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_232bd_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_232bd_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_232bd_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_232bd_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_232bd_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_232bd_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_232bd_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_232bd_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_232bd_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_232bd_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_232bd_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_232bd_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_232bd_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_232bd_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_232bd_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_232bd_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_232bd_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_232bd_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_232bd_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_232bd_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_232bd_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_232bd_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_232bd_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_232bd_row19_col1" class="data row19 col1" >952d</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_70260 th {
#   text-align: left;
# }
# #T_70260_row0_col0, #T_70260_row1_col0, #T_70260_row1_col1, #T_70260_row1_col2, #T_70260_row1_col3, #T_70260_row1_col4, #T_70260_row1_col5, #T_70260_row1_col6, #T_70260_row1_col7, #T_70260_row2_col0, #T_70260_row2_col1, #T_70260_row2_col2, #T_70260_row2_col3, #T_70260_row2_col4, #T_70260_row2_col5, #T_70260_row2_col6, #T_70260_row2_col7, #T_70260_row3_col0, #T_70260_row3_col1, #T_70260_row3_col2, #T_70260_row3_col3, #T_70260_row3_col4, #T_70260_row3_col5, #T_70260_row3_col6, #T_70260_row3_col7, #T_70260_row4_col0, #T_70260_row4_col1, #T_70260_row4_col2, #T_70260_row4_col3, #T_70260_row4_col4, #T_70260_row4_col5, #T_70260_row4_col6, #T_70260_row4_col7, #T_70260_row5_col0, #T_70260_row5_col1, #T_70260_row5_col2, #T_70260_row5_col3, #T_70260_row5_col4, #T_70260_row5_col5, #T_70260_row5_col6, #T_70260_row5_col7, #T_70260_row6_col0, #T_70260_row6_col1, #T_70260_row6_col2, #T_70260_row6_col3, #T_70260_row6_col4, #T_70260_row6_col5, #T_70260_row6_col6, #T_70260_row6_col7, #T_70260_row7_col0, #T_70260_row7_col1, #T_70260_row7_col2, #T_70260_row7_col3, #T_70260_row7_col4, #T_70260_row7_col5, #T_70260_row7_col6, #T_70260_row7_col7, #T_70260_row8_col0, #T_70260_row8_col1, #T_70260_row8_col2, #T_70260_row8_col3, #T_70260_row8_col4, #T_70260_row8_col5, #T_70260_row8_col6, #T_70260_row8_col7, #T_70260_row9_col0, #T_70260_row9_col1, #T_70260_row9_col2, #T_70260_row9_col3, #T_70260_row9_col4, #T_70260_row9_col5, #T_70260_row9_col6, #T_70260_row9_col7, #T_70260_row10_col0, #T_70260_row10_col1, #T_70260_row10_col2, #T_70260_row10_col3, #T_70260_row10_col4, #T_70260_row10_col5, #T_70260_row10_col6, #T_70260_row10_col7, #T_70260_row11_col0, #T_70260_row11_col1, #T_70260_row11_col2, #T_70260_row11_col3, #T_70260_row11_col4, #T_70260_row11_col5, #T_70260_row11_col6, #T_70260_row11_col7, #T_70260_row12_col0, #T_70260_row12_col1, #T_70260_row12_col2, #T_70260_row12_col3, #T_70260_row12_col4, #T_70260_row12_col5, #T_70260_row12_col6, #T_70260_row12_col7, #T_70260_row13_col0, #T_70260_row13_col1, #T_70260_row13_col2, #T_70260_row13_col3, #T_70260_row13_col4, #T_70260_row13_col5, #T_70260_row13_col6, #T_70260_row13_col7, #T_70260_row14_col0, #T_70260_row14_col1, #T_70260_row14_col2, #T_70260_row14_col3, #T_70260_row14_col4, #T_70260_row14_col5, #T_70260_row14_col6, #T_70260_row14_col7 {
#   text-align: left;
# }
# #T_70260_row0_col1, #T_70260_row0_col2, #T_70260_row0_col3, #T_70260_row0_col4, #T_70260_row0_col5, #T_70260_row0_col6, #T_70260_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_70260_row0_col8, #T_70260_row1_col8, #T_70260_row3_col8, #T_70260_row4_col8, #T_70260_row5_col8, #T_70260_row6_col8, #T_70260_row7_col8, #T_70260_row8_col8, #T_70260_row9_col8, #T_70260_row10_col8, #T_70260_row11_col8, #T_70260_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_70260_row2_col8, #T_70260_row13_col8, #T_70260_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_70260">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70260_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_70260_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_70260_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_70260_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_70260_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_70260_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_70260_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_70260_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_70260_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70260_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_70260_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_70260_row0_col1" class="data row0 col1" >0.7653</td>
#       <td id="T_70260_row0_col2" class="data row0 col2" >0.9042</td>
#       <td id="T_70260_row0_col3" class="data row0 col3" >0.7653</td>
#       <td id="T_70260_row0_col4" class="data row0 col4" >0.7513</td>
#       <td id="T_70260_row0_col5" class="data row0 col5" >0.7531</td>
#       <td id="T_70260_row0_col6" class="data row0 col6" >0.6135</td>
#       <td id="T_70260_row0_col7" class="data row0 col7" >0.6184</td>
#       <td id="T_70260_row0_col8" class="data row0 col8" >1.0640</td>
#     </tr>
#     <tr>
#       <th id="T_70260_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_70260_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_70260_row1_col1" class="data row1 col1" >0.7528</td>
#       <td id="T_70260_row1_col2" class="data row1 col2" >0.8883</td>
#       <td id="T_70260_row1_col3" class="data row1 col3" >0.7528</td>
#       <td id="T_70260_row1_col4" class="data row1 col4" >0.7445</td>
#       <td id="T_70260_row1_col5" class="data row1 col5" >0.7411</td>
#       <td id="T_70260_row1_col6" class="data row1 col6" >0.5943</td>
#       <td id="T_70260_row1_col7" class="data row1 col7" >0.6006</td>
#       <td id="T_70260_row1_col8" class="data row1 col8" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_70260_level0_row2" class="row_heading level0 row2" >qda</th>
#       <td id="T_70260_row2_col0" class="data row2 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_70260_row2_col1" class="data row2 col1" >0.7528</td>
#       <td id="T_70260_row2_col2" class="data row2 col2" >0.8941</td>
#       <td id="T_70260_row2_col3" class="data row2 col3" >0.7528</td>
#       <td id="T_70260_row2_col4" class="data row2 col4" >0.7460</td>
#       <td id="T_70260_row2_col5" class="data row2 col5" >0.7464</td>
#       <td id="T_70260_row2_col6" class="data row2 col6" >0.5984</td>
#       <td id="T_70260_row2_col7" class="data row2 col7" >0.6011</td>
#       <td id="T_70260_row2_col8" class="data row2 col8" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_70260_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_70260_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_70260_row3_col1" class="data row3 col1" >0.7507</td>
#       <td id="T_70260_row3_col2" class="data row3 col2" >0.8985</td>
#       <td id="T_70260_row3_col3" class="data row3 col3" >0.7507</td>
#       <td id="T_70260_row3_col4" class="data row3 col4" >0.7407</td>
#       <td id="T_70260_row3_col5" class="data row3 col5" >0.7407</td>
#       <td id="T_70260_row3_col6" class="data row3 col6" >0.5901</td>
#       <td id="T_70260_row3_col7" class="data row3 col7" >0.5951</td>
#       <td id="T_70260_row3_col8" class="data row3 col8" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_70260_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_70260_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_70260_row4_col1" class="data row4 col1" >0.7455</td>
#       <td id="T_70260_row4_col2" class="data row4 col2" >0.8853</td>
#       <td id="T_70260_row4_col3" class="data row4 col3" >0.7455</td>
#       <td id="T_70260_row4_col4" class="data row4 col4" >0.7350</td>
#       <td id="T_70260_row4_col5" class="data row4 col5" >0.7339</td>
#       <td id="T_70260_row4_col6" class="data row4 col6" >0.5829</td>
#       <td id="T_70260_row4_col7" class="data row4 col7" >0.5882</td>
#       <td id="T_70260_row4_col8" class="data row4 col8" >0.0570</td>
#     </tr>
#     <tr>
#       <th id="T_70260_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_70260_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_70260_row5_col1" class="data row5 col1" >0.7455</td>
#       <td id="T_70260_row5_col2" class="data row5 col2" >0.8801</td>
#       <td id="T_70260_row5_col3" class="data row5 col3" >0.7455</td>
#       <td id="T_70260_row5_col4" class="data row5 col4" >0.7418</td>
#       <td id=

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier
from lightgbm import LGBMClassifier

how_many_model = 5
models = []
for mod in best_model[:how_many_model]:
    exec('model = mod')
    models.append((str(model).split('(')[0], model))
print(models)
ensemble_hit = VotingClassifier(models)
ensemble_hit.fit(X_hitter_train, Y_hitter_train)
y_pred = ensemble_hit.predict(X_hitter_train)
# Out:
# [('LogisticRegression', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=8968, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)), ('RandomForestClassifier', RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=8968, verbose=0, warm_start=False)), ('QuadraticDiscriminantAnalysis', QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)), ('LinearDiscriminantAnalysis', LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001)), ('ExtraTreesClassifier', ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      n_estimators=100, n_jobs=-1, oob_score=False,
#                      random_state=8968, verbose=0, warm_start=False))]

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(Y_hitter_train, y_pred)
print(f"Accuracy: {acc:.4f}")

y_test_pred = ensemble_hit.predict(X_hitter_test)
acc_test = accuracy_score(Y_hitter_test, y_test_pred)
print(f"Test Accuracy: {acc_test:.4f}")
# Out:
# Accuracy: 0.8478
# Test Accuracy: 0.7694

# %%
hit_2023_data = pd.read_csv('../raw_data/2023 hitters.csv')
hit_2023 = hit_2023_data.drop(['순','이름','팀','WAR*.1'], axis = 1)
hit_2023 = ct_hit.transform(hit_2023)

pred_hit_2023 = ensemble_hit.predict(hit_2023)
unique_values, counts = np.unique(pred_hit_2023, return_counts=True)
for value, count in zip(unique_values, counts):
  print(f"{value}: {count}")

hit_2023_data['label'] = pred_hit_2023
# Out:
# 1: 175
# 2: 55
# 3: 57

# %%
hit_2023_data.to_csv('../raw_data/2023 KBO Salary Prediction - Hitter.csv', index = False)

# %% [markdown]
# # pycaret - 투수

# %%
from pycaret.classification import *

exp1 = setup(data = pitcher_data, target = 'label')
best_model = compare_models(n_select=10)
# Out:
# <style type="text/css">
# #T_d3e00_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d3e00">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3e00_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d3e00_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3e00_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3e00_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d3e00_row0_col1" class="data row0 col1" >3290</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3e00_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d3e00_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3e00_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d3e00_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3e00_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_d3e00_row3_col1" class="data row3 col1" >1: 0, 2: 1, 3: 2</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3e00_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_d3e00_row4_col1" class="data row4 col1" >(1240, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d3e00_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_d3e00_row5_col1" class="data row5 col1" >(1240, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d3e00_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_d3e00_row6_col1" class="data row6 col1" >(868, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d3e00_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_d3e00_row7_col1" class="data row7 col1" >(372, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d3e00_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_d3e00_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d3e00_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_d3e00_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d3e00_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_d3e00_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d3e00_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_d3e00_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d3e00_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_d3e00_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d3e00_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_d3e00_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d3e00_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_d3e00_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d3e00_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_d3e00_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d3e00_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_d3e00_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d3e00_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_d3e00_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d3e00_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_d3e00_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d3e00_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d3e00_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_d3e00_row19_col1" class="data row19 col1" >d0c7</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6d32b th {
#   text-align: left;
# }
# #T_6d32b_row0_col0, #T_6d32b_row0_col2, #T_6d32b_row0_col4, #T_6d32b_row1_col0, #T_6d32b_row1_col1, #T_6d32b_row1_col2, #T_6d32b_row1_col3, #T_6d32b_row1_col4, #T_6d32b_row1_col5, #T_6d32b_row1_col6, #T_6d32b_row1_col7, #T_6d32b_row2_col0, #T_6d32b_row2_col1, #T_6d32b_row2_col2, #T_6d32b_row2_col3, #T_6d32b_row2_col4, #T_6d32b_row2_col5, #T_6d32b_row2_col6, #T_6d32b_row2_col7, #T_6d32b_row3_col0, #T_6d32b_row3_col1, #T_6d32b_row3_col3, #T_6d32b_row3_col4, #T_6d32b_row3_col5, #T_6d32b_row3_col6, #T_6d32b_row3_col7, #T_6d32b_row4_col0, #T_6d32b_row4_col1, #T_6d32b_row4_col2, #T_6d32b_row4_col3, #T_6d32b_row4_col4, #T_6d32b_row4_col5, #T_6d32b_row4_col6, #T_6d32b_row4_col7, #T_6d32b_row5_col0, #T_6d32b_row5_col1, #T_6d32b_row5_col2, #T_6d32b_row5_col3, #T_6d32b_row5_col4, #T_6d32b_row5_col5, #T_6d32b_row5_col6, #T_6d32b_row5_col7, #T_6d32b_row6_col0, #T_6d32b_row6_col1, #T_6d32b_row6_col2, #T_6d32b_row6_col3, #T_6d32b_row6_col4, #T_6d32b_row6_col5, #T_6d32b_row6_col6, #T_6d32b_row6_col7, #T_6d32b_row7_col0, #T_6d32b_row7_col1, #T_6d32b_row7_col2, #T_6d32b_row7_col3, #T_6d32b_row7_col4, #T_6d32b_row7_col5, #T_6d32b_row7_col6, #T_6d32b_row7_col7, #T_6d32b_row8_col0, #T_6d32b_row8_col1, #T_6d32b_row8_col2, #T_6d32b_row8_col3, #T_6d32b_row8_col4, #T_6d32b_row8_col5, #T_6d32b_row8_col6, #T_6d32b_row8_col7, #T_6d32b_row9_col0, #T_6d32b_row9_col1, #T_6d32b_row9_col2, #T_6d32b_row9_col3, #T_6d32b_row9_col5, #T_6d32b_row9_col6, #T_6d32b_row9_col7, #T_6d32b_row10_col0, #T_6d32b_row10_col1, #T_6d32b_row10_col2, #T_6d32b_row10_col3, #T_6d32b_row10_col4, #T_6d32b_row10_col5, #T_6d32b_row10_col6, #T_6d32b_row10_col7, #T_6d32b_row11_col0, #T_6d32b_row11_col1, #T_6d32b_row11_col2, #T_6d32b_row11_col3, #T_6d32b_row11_col4, #T_6d32b_row11_col5, #T_6d32b_row11_col6, #T_6d32b_row11_col7, #T_6d32b_row12_col0, #T_6d32b_row12_col1, #T_6d32b_row12_col2, #T_6d32b_row12_col3, #T_6d32b_row12_col4, #T_6d32b_row12_col5, #T_6d32b_row12_col6, #T_6d32b_row12_col7, #T_6d32b_row13_col0, #T_6d32b_row13_col1, #T_6d32b_row13_col2, #T_6d32b_row13_col3, #T_6d32b_row13_col4, #T_6d32b_row13_col5, #T_6d32b_row13_col6, #T_6d32b_row13_col7, #T_6d32b_row14_col0, #T_6d32b_row14_col1, #T_6d32b_row14_col2, #T_6d32b_row14_col3, #T_6d32b_row14_col4, #T_6d32b_row14_col5, #T_6d32b_row14_col6, #T_6d32b_row14_col7 {
#   text-align: left;
# }
# #T_6d32b_row0_col1, #T_6d32b_row0_col3, #T_6d32b_row0_col5, #T_6d32b_row0_col6, #T_6d32b_row0_col7, #T_6d32b_row3_col2, #T_6d32b_row9_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6d32b_row0_col8, #T_6d32b_row1_col8, #T_6d32b_row2_col8, #T_6d32b_row3_col8, #T_6d32b_row5_col8, #T_6d32b_row6_col8, #T_6d32b_row8_col8, #T_6d32b_row9_col8, #T_6d32b_row10_col8, #T_6d32b_row11_col8, #T_6d32b_row12_col8, #T_6d32b_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6d32b_row4_col8, #T_6d32b_row7_col8, #T_6d32b_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6d32b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d32b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6d32b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6d32b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6d32b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6d32b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6d32b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6d32b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6d32b_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_6d32b_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d32b_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_6d32b_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_6d32b_row0_col1" class="data row0 col1" >0.6971</td>
#       <td id="T_6d32b_row0_col2" class="data row0 col2" >0.8458</td>
#       <td id="T_6d32b_row0_col3" class="data row0 col3" >0.6971</td>
#       <td id="T_6d32b_row0_col4" class="data row0 col4" >0.6944</td>
#       <td id="T_6d32b_row0_col5" class="data row0 col5" >0.6903</td>
#       <td id="T_6d32b_row0_col6" class="data row0 col6" >0.5026</td>
#       <td id="T_6d32b_row0_col7" class="data row0 col7" >0.5067</td>
#       <td id="T_6d32b_row0_col8" class="data row0 col8" >0.0660</td>
#     </tr>
#     <tr>
#       <th id="T_6d32b_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_6d32b_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_6d32b_row1_col1" class="data row1 col1" >0.6844</td>
#       <td id="T_6d32b_row1_col2" class="data row1 col2" >0.8434</td>
#       <td id="T_6d32b_row1_col3" class="data row1 col3" >0.6844</td>
#       <td id="T_6d32b_row1_col4" class="data row1 col4" >0.6847</td>
#       <td id="T_6d32b_row1_col5" class="data row1 col5" >0.6777</td>
#       <td id="T_6d32b_row1_col6" class="data row1 col6" >0.4841</td>
#       <td id="T_6d32b_row1_col7" class="data row1 col7" >0.4893</td>
#       <td id="T_6d32b_row1_col8" class="data row1 col8" >0.0750</td>
#     </tr>
#     <tr>
#       <th id="T_6d32b_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_6d32b_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6d32b_row2_col1" class="data row2 col1" >0.6798</td>
#       <td id="T_6d32b_row2_col2" class="data row2 col2" >0.8379</td>
#       <td id="T_6d32b_row2_col3" class="data row2 col3" >0.6798</td>
#       <td id="T_6d32b_row2_col4" class="data row2 col4" >0.6761</td>
#       <td id="T_6d32b_row2_col5" class="data row2 col5" >0.6736</td>
#       <td id="T_6d32b_row2_col6" class="data row2 col6" >0.4759</td>
#       <td id="T_6d32b_row2_col7" class="data row2 col7" >0.4795</td>
#       <td id="T_6d32b_row2_col8" class="data row2 col8" >0.6080</td>
#     </tr>
#     <tr>
#       <th id="T_6d32b_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_6d32b_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_6d32b_row3_col1" class="data row3 col1" >0.6797</td>
#       <td id="T_6d32b_row3_col2" class="data row3 col2" >0.8474</td>
#       <td id="T_6d32b_row3_col3" class="data row3 col3" >0.6797</td>
#       <td id="T_6d32b_row3_col4" class="data row3 col4" >0.6762</td>
#       <td id="T_6d32b_row3_col5" class="data row3 col5" >0.6710</td>
#       <td id="T_6d32b_row3_col6" class="data row3 col6" >0.4714</td>
#       <td id="T_6d32b_row3_col7" class="data row3 col7" >0.4771</td>
#       <td id="T_6d32b_row3_col8" class="data row3 col8" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_6d32b_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_6d32b_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_6d32b_row4_col1" class="data row4 col1" >0.6797</td>
#       <td id="T_6d32b_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_6d32b_row4_col3" class="data row4 col3" >0.6797</td>
#       <td id="T_6d32b_row4_col4" class="data row4 col4" >0.6680</td>
#       <td id="T_6d32b_row4_col5" class="data row4 col5" >0.6634</td>
#       <td id="T_6d32b_row4_col6" class="data row4 col6" >0.4630</td>
#       <td id="T_6d32b_row4_col7" class="data row4 col7" >0.4720</td>
#       <td id="T_6d32b_row4_col8" class="data row4 col8" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_6d32b_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_6d32b_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_6d32b_row5_col1" class="data row5 col1" >0.6764</td>
#       <td id="T_6d32b_row5_col2" class="data row5 col2" >0.8316</td>
#       <td id="T_6d32b_row5_col3" class="data row5 col3" >0.6764</td>
#       <td id="T_6d32b_row5_col4" class="data row5 col4" >0.6775</td>
#       <td id="T_6d32b_row

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier
from lightgbm import LGBMClassifier

how_many_model = 5
models = []
for mod in best_model[:how_many_model]:
    exec('model = mod')
    models.append((str(model).split('(')[0], model))
print(models)
ensemble_pit = VotingClassifier(models)
ensemble_pit.fit(X_pitcher_train, Y_pitcher_train)
y_pred = ensemble_pit.predict(X_pitcher_train)
# Out:
# [('ExtraTreesClassifier', ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      n_estimators=100, n_jobs=-1, oob_score=False,
#                      random_state=3290, verbose=0, warm_start=False)), ('RandomForestClassifier', RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=3290, verbose=0, warm_start=False)), ('LGBMClassifier', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=3290, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)), ('LogisticRegression', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=3290, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)), ('RidgeClassifier', RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, positive=False, random_state=3290, solver='auto',
#                 tol=0.0001))]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000657 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1687
# [LightGBM] [Info] Number of data points in the train set: 868, number of used features: 10
# [LightGBM] [Info] Start training from score -0.702407
# [LightGBM] [Info] Start training from score -1.323774
# [LightGBM] [Info] Start training from score -1.433473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(Y_pitcher_train, y_pred)
print(f"Accuracy: {acc:.4f}")

y_test_pred = ensemble_pit.predict(X_pitcher_test)
acc_test = accuracy_score(Y_pitcher_test, y_test_pred)
print(f"Test Accuracy: {acc_test:.4f}")
# Out:
# Accuracy: 0.9885
# Test Accuracy: 0.7151

# %%
pit_2023_data = pd.read_csv('../raw_data/2023 pitchers.csv')
pit_2023 = pit_2023_data.drop(['순','이름','팀','WAR(need to drop)'], axis = 1)
pit_2023 = ct_pit.transform(pit_2023)

pred_pit_2023 = ensemble_pit.predict(pit_2023)
unique_values, counts = np.unique(pred_pit_2023, return_counts = True)
for value, count in zip(unique_values, counts):
  print(f"{value}: {count}")

pit_2023_data['label'] = pred_pit_2023
# Out:
# 1: 169
# 2: 53
# 3: 48

# %%
pit_2023_data.to_csv('../raw_data/2023 KBO Salary Prediction - Pitcher.csv',index = False)

# %%
hitter
# Out:
#       index   이름  WAR*    G   타석   타수   득점   안타  2타  3타  ...     출루     장타  \
# 0         1  이정후  9.23  142  627  553   85  193  36  10  ...  0.421  0.575
# 1         5  김재환  7.46  144  636  544  110  185  34   2  ...  0.429  0.603
# 2         6  피렐라  7.40  141  630  561  102  192  33   4  ...  0.411  0.565
# 3         7  김하성  7.17  139  625  540  112  166  38   2  ...  0.389  0.491
# 4         8  박건우  7.01  131  543  483   91  177  40   2  ...  0.424  0.582
# ...     ...  ...   ...  ...  ...  ...  ...  ...  ..  ..  ...    ...    ...
# 1366   2244  박종윤 -1.23   98  326  314   29   80  11   3  ...  0.277  0.347
# 1367   2245  정범모 -1.25   51  114   96    3   13   2   0  ...  0.215  0.156
# 1368   2247  강한울 -1.39   90  292  264   30   54   8   3  ...  0.250  0.258
# 1369   2248  나종덕 -1.41  104  209  185   12   23   4   0  ...  0.188  0.195
# 1370   2249  김헌곤 -1.58   80  239  224   18   43   8   0  ...  0.224  0.241
#
#         OPS   wOBA   wRC+   WPA  소속팀    연도  포지션  label
# 0     0.996  0.441  182.5  6.72   키움  2022   CF      3
# 1     1.032  0.440  170.9  7.45   두산  2017   LF      3
# 2     0.976  0.434  169.3  4.20   삼성  2022   LF      3
# 3     0.880  0.397  145.7  4.52   키움  2019   SS      3
# 4     1.006  0.433  163.8  2.76   두산  2017   CF      3
# ...     ...    ...    ...   ...  ...   ...  ...    ...
# 1366  0.624  0.279   54.0 -1.97   롯데  2015   1B      2
# 1367  0.371  0.177  -16.3 -1.10   한화  2015    C      1
# 1368  0.508  0.229   18.5 -1.36  KIA  2015   SS      1
# 1369  0.383  0.180   -4.2 -2.74   롯데  2019    C      1
# 1370  0.465  0.217   24.6 -2.24   삼성  2022   CF      2
#
# [1371 rows x 33 columns]

# %%
pitcher
# Out:
#       index     이름   WAR  출장  완투  완봉  선발   승   패  세  ...  폭투   ERA   FIP  \
# 0         1    양현종  8.14  32   1   1  31  15   6  0  ...   6  2.44  4.57
# 1         2    안우진  7.92  30   1   0  30  15   8  0  ...   7  2.11  2.21
# 2         3  스트레일리  7.53  31   0   0  31  15   4  0  ...   4  2.50  3.01
# 3         4  스트레일리  7.53  31   0   0  31  15   4  0  ...   4  2.50  3.01
# 4         5    양현종  7.35  29   2   2  29  16   8  0  ...   1  2.29  2.63
# ...     ...    ...   ...  ..  ..  ..  ..  ..  .. ..  ...  ..   ...   ...
# 1235   2045    황동재 -1.29  16   0   0  13   1   3  0  ...   1  7.06  4.91
# 1236   2047    김대우 -1.32  25   0   0   7   2   5  0  ...   2  9.54  6.48
# 1237   2048    윤대경 -1.37  25   0   0  14   4   9  0  ...   5  7.41  3.98
# 1238   2049    장시환 -1.38  19   1   0  16   0  11  0  ...   7  7.04  4.99
# 1239   2051    배영수 -1.55  32   0   0  21   4  11  0  ...   6  7.04  6.78
#
#       WHIP   ERA+   FIP+   WPA  소속팀    연도  label
# 0     1.24  202.1  108.5  3.94  KIA  2015      3
# 1     0.95  189.3  179.1  5.65   키움  2022      2
# 2     1.02  195.1  159.0  3.84   롯데  2020      3
# 3     1.02  195.1  159.0  3.84   롯데  2020      3
# 4     1.07  183.1  160.3  3.81  KIA  2019      3
# ...    ...    ...    ...   ...  ...   ...    ...
# 1235  1.84   59.2   84.6 -1.89   삼성  2022      1
# 1236  1.94   53.2   77.7 -2.63   삼성  2017      2
# 1237  1.63   54.7  102.6 -2.23   한화  2022      2
# 1238  1.96   62.2   89.5 -2.32   한화  2021      2
# 1239  1.61   70.8   72.9 -3.88   한화  2015      3
#
# [1240 rows x 34 columns]
